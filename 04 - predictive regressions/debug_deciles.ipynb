# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Directories
CODE_DIR = Path(r"C:\Users\willi\.vscode\Github\ml-from-crowd")
DATA_DIR = Path(r"E:\Research_data\Stocktwits\dataset\v1\data\csv")
FIGURES_DIR = Path(r"C:\Users\willi\.vscode\Github\Figures")
MODEL_DATA_DIR = Path(r"C:\Users\willi\.vscode\Github\Data")

# Load predictions for the 2-feature linear model
preds = pd.read_pickle(MODEL_DATA_DIR / "predictions_linear_regression_input=2.pkl")
preds['date'] = pd.to_datetime(preds['date'])

print(f"Shape: {preds.shape}")
print(f"Columns: {list(preds.columns)}")
print(f"Date range: {preds['date'].min().date()} to {preds['date'].max().date()}")
preds.head()
# Out:
# Shape: (13327784, 5)
# Columns: ['date', 'permno', 'ticker', 'index', 'prediction']
# Date range: 2012-01-03 to 2023-12-29
#         date  permno ticker    index  prediction
# 0 2012-01-03   87432      A  2879304   -0.000188
# 1 2012-01-03   24643     AA  2377768   -0.000188
# 2 2012-01-03   12479    AAC  2266267   -0.000188
# 3 2012-01-03   90020   AACC  2994307   -0.000188
# 4 2012-01-03   15580   AAME  2343833   -0.000188

# %%
# Pick a single date in January 2012
target_date = preds[preds['date'].dt.to_period('M') == '2012-01']['date'].unique()[0]
day = preds[preds['date'] == target_date].copy()

print(f"Date: {target_date.date()}")
print(f"Number of stocks: {len(day):,}")
print(f"\nPrediction distribution:")
print(day['prediction'].describe())
# Out:
# Date: 2012-01-03
# Number of stocks: 4,219
#
# Prediction distribution:
# count    4219.000000
# mean       -0.000213
# std         0.000211
# min        -0.001350
# 25%        -0.000188
# 50%        -0.000188
# 75%        -0.000188
# max         0.001621
# Name: prediction, dtype: float64

# %%
# Number of unique prediction values
n_unique = day['prediction'].nunique()
print(f"Unique prediction values: {n_unique:,} out of {len(day):,} stocks")
print(f"\nValue counts of most common predictions:")
print(day['prediction'].value_counts().head(20))
# Out:
# Unique prediction values: 12 out of 4,219 stocks
#
# Value counts of most common predictions:
# prediction
# -0.000188    4084
# -0.001350      92
# -0.001223      18
#  0.001405      13
# -0.001133       4
#  0.001531       2
# -0.000959       1
#  0.001621       1
# -0.000543       1
# -0.001064       1
# -0.000375       1
#  0.000154       1
# Name: count, dtype: int64

# %%
# Split into deciles using pd.qcut
day['decile'] = pd.qcut(day['prediction'].rank(method='first'), 10, labels=False) + 1

# Stocks per decile
print("Stocks per decile:")
print(day.groupby('decile').size().to_string())

# Breakpoints
print("\nPrediction range per decile:")
decile_stats = day.groupby('decile')['prediction'].agg(['min', 'max', 'mean', 'count'])
print(decile_stats.to_string())
# Out:
# Stocks per decile:
# decile
# 1     422
# 2     422
# 3     422
# 4     422
# 5     422
# 6     421
# 7     422
# 8     422
# 9     422
# 10    422
#
# Prediction range per decile:
#              min       max      mean  count
# decile
# 1      -0.001350 -0.000188 -0.000500    422
# 2      -0.000188 -0.000188 -0.000188    422
# 3      -0.000188 -0.000188 -0.000188    422
# 4      -0.000188 -0.000188 -0.000188    422
# 5      -0.000188 -0.000188 -0.000188    422
# 6      -0.000188 -0.000188 -0.000188    421
# 7      -0.000188 -0.000188 -0.000188    422
# 8      -0.000188 -0.000188 -0.000188    422
# 9      -0.000188 -0.000188 -0.000188    422
# 10     -0.000188  0.001621 -0.000126    422
